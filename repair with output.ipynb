# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import numpy as np
import scipy as sp
import math
from scipy.integrate import odeint
from scipy.stats import poisson
from scipy.stats import norm
from scipy.stats import lognorm

import os
import sys
import io
from contextlib import redirect_stdout

from repairanalysis import medrasrepair
from repairanalysis import sddparser
from itertools import groupby

path = os.getcwd()

# %%
sddpath = path


#print('Fidelity analysis')
#fide = medrasrepair.repairSimulation(sddpath,'Fidelity', 24)

print('\n\nMisrepair spectrum analysis')
medrasrepair.repairSimulation(sddpath,'Spectrum')
# Out:
# Misrepair spectrum analysis
# From folder:	 /content/
#
# Data for: n5MeV_inner_alpha_3_SDDOutput.txt
# Index	Breaks	Residual	Misrepairs	Large Misrepairs	Inter-Chromosome Misrepairs		Dicentric Aberrations	Rings Aberrations	Excess Linear Fragments	Total Aberrations		Viability
# 0 	 47 	 0 	 40	3	2		0 	 0 	 0 	 0		1

# %%
'''
individual break set field:
    0 is file name
    1 is break set
    2 is break count
    3 is misrepair (in DSB? in fractional?)
    4 is misrepair standard deviation
    5 is inter-chromosome rate

    print('File\tBreak Set\tBreak Count\tMisrepair\tStdev\tInter-Chromosome Rate', end='')


summary field:
    0 is file name
    1 is break set (summary)
    2 is total break count
    3 is complexity (unit? how is it counted?)
    4 is average break count
    5 is average break count's standard deviation
    6 is average misrepairs
    7 is misrepair standard deviation
    8 is file average (of what? error rate? whatever that is)

	smry = (fileName+'\tSummary\t'+str(totalBreaks)+'\t'+str(complexity)+'\t'+str(averageBreaks)+
		   '\t'+str(breakStdev)+'\t'+str(averageMisrep)+'\t'+str(misrepStdev)+'\t'+
		   str(fileAverages[0]) )
'''

'''
individual break set field:
    0 is break set (index that starts at 0)
    1 is number of breaks
    2 is residual (number of DSB that remains)
    3 is number of misrepairs (include large misrepairs?)
    4 is number of large misrepairs (larger than 3 MBP)
    5 is inter-chromosome misrepairs
    6 is the # of dicentrics
    7 is the # of rings
    8 is the # of excess linear fragments
    9 is the # of total aberrations
    10 is the viability

'''
# Out:
# '\nindividual break set field:\n    0 is break set (index that starts at 0)\n    1 is number of breaks\n    2 is residual (number of DSB that remains)\n    3 is number of misrepairs (include large misrepairs?)\n    4 is number of large misrepairs (larger than 3 MBP)\n    5 is inter-chromosome misrepairs\n    6 is the # of dicentrics\n    7 is the # of rings\n    8 is the # of excess linear fragments\n    9 is the # of total aberrations\n    10 is the viability\n\n'

# %%
def run_simulation(sddp, mode):
    # Create an in-memory text stream
    memory_file = io.StringIO()

    if mode == 'Fidelity':
      # Redirect stdout to the in-memory stream
      with redirect_stdout(memory_file):
          medrasrepair.repairSimulation(sddpath,'Fidelity', 24)

      # Reset the stream position to the beginning
      memory_file.seek(0)

      # Read the data from the in-memory stream
      repair_data = [line.split() for line in memory_file]# if line[0].isdigit()]

      # Close the in-memory stream
      memory_file.close()

      return repair_data

    elif mode == 'Spectrum':
      # Redirect stdout to the in-memory stream
      with redirect_stdout(memory_file):
          medrasrepair.repairSimulation(sddp, 'Spectrum')

      # Reset the stream position to the beginning
      memory_file.seek(0)

      # Read the data from the in-memory stream
      repair_data = [line.split() for line in memory_file if line[0].isdigit()]

      # Close the in-memory stream
      memory_file.close()

      return repair_data
    else:
      print('Invalid mode')
      return None

# %%
for line in run_simulation(sddpath, 'Fidelity'):
    print(line)
# Out:
# ['From', 'folder:', '/content/']
# []
# ['n5MeV_inner_alpha_3_SDDOutput.txt', 'Read:', '1', 'sets', 'of', 'breaks,', 'with', 'average', 'complexity', '0.3191489361702128', ',', 'stdev:', '0.0', '.', 'Also', 'read', '0', 'empty', 'break', 'sets.']
# ['File', 'Break', 'Set', 'Break', 'Count', 'Misrepair', 'Stdev', 'Inter-Chromosome', 'Rate']
# ['n5MeV_inner_alpha_3_SDDOutput.txt', '0', '47.0', '0.8995744680851064', '0.035866055328860384', '0.056291390728476824']
# []
# ['n5MeV_inner_alpha_3_SDDOutput.txt', 'Summary', '47.0', '0.3191489361702128', '47.0', '0.0', '0.8995744680851064', '0.0', '0.056291390728476824', 'n5MeV_inner_alpha_3_SDDOutput.txt', '1', '0.9872340425531915', '0.9736170212765958', '0.9629787234042553', '0.9553191489361702', '0.9463829787234043', '0.9425531914893617', '0.9370212765957446', '0.934468085106383', '0.9319148936170213', '0.9306382978723404', '0.9297872340425531', '0.928936170212766', '0.9242553191489362', '0.9234042553191489', '0.9225531914893617', '0.9208510638297872', '0.9191489361702128', '0.9178723404255319', '0.9161702127659574', '0.914468085106383', '0.9131914893617021', '0.9106382978723404', '0.908936170212766', '0.9059574468085106', '0.9038297872340426', '0.9008510638297872', '0.8991489361702127', '0.8961702127659574', '0.8931914893617021', '0.892340425531915', '0.8906382978723404', '0.8902127659574468', '0.8893617021276596', '0.8872340425531915', '0.8842553191489362', '0.8829787234042553', '0.8808510638297873', '0.8791489361702127', '0.8770212765957447', '0.8757446808510638', '0.8731914893617021', '0.8723404255319149', '0.8693617021276596', '0.8689361702127659', '0.8685106382978723', '0.8668085106382979', '0.8646808510638297', '0.8629787234042553', '0.8591489361702127', '0.857872340425532', '0.8565957446808511', '0.854468085106383', '0.8523404255319149', '0.8485106382978723', '0.847659574468085', '0.8463829787234043', '0.843404255319149', '0.8421276595744681', '0.84', '0.8387234042553191', '0.8378723404255319', '0.8370212765957447', '0.8348936170212766', '0.8340425531914893', '0.8331914893617021', '0.8323404255319149', '0.8306382978723404', '0.8293617021276596', '0.828936170212766', '0.8263829787234043', '0.8251063829787234', '0.8242553191489361', '0.823404255319149', '0.8221276595744681', '0.8208510638297872', '0.8191489361702128', '0.8178723404255319', '0.8157446808510638', '0.8131914893617022', '0.811063829787234', '0.8097872340425532', '0.8093617021276596', '0.8076595744680851', '0.8059574468085107', '0.8051063829787234', '0.8021276595744681', '0.8004255319148936', '0.7991489361702128', '0.7982978723404255', '0.796595744680851', '0.7940425531914894', '0.7931914893617021', '0.7919148936170213', '0.7902127659574468', '0.788936170212766', '0.7880851063829787', '0.7863829787234042', '0.7846808510638298', '0.7846808510638298', '0.7829787234042553', '0.7817021276595745', '0.7808510638297872', '0.7804255319148936', '0.7787234042553192', '0.7765957446808511', '0.7765957446808511', '0.7753191489361702', '0.7731914893617021', '0.7714893617021277', '0.7702127659574468', '0.7672340425531915', '0.7672340425531915', '0.7668085106382979', '0.7651063829787235', '0.7625531914893617', '0.7617021276595745', '0.7595744680851064', '0.7591489361702127', '0.7582978723404256', '0.7574468085106383', '0.7565957446808511', '0.7557446808510638', '0.7557446808510638', '0.7548936170212766', '0.7540425531914894', '0.7523404255319148', '0.7514893617021277', '0.7510638297872341', '0.7506382978723405', '0.7485106382978723', '0.7480851063829788', '0.7468085106382979', '0.7463829787234042', '0.745531914893617', '0.7442553191489362', '0.7434042553191489', '0.7429787234042553', '0.7421276595744681', '0.7412765957446809', '0.7412765957446809', '0.7382978723404255', '0.7378723404255318', '0.7374468085106383', '0.7365957446808511', '0.7353191489361702', '0.7327659574468085', '0.7323404255319149', '0.7314893617021276', '0.731063829787234', '0.7302127659574469', '0.7280851063829787', '0.7259574468085106', '0.725531914893617', '0.7221276595744681', '0.7208510638297873', '0.7195744680851064', '0.7178723404255319', '0.7165957446808511', '0.7161702127659575', '0.7144680851063829', '0.7127659574468085', '0.7119148936170212', '0.711063829787234', '0.7097872340425532', '0.7080851063829787', '0.7068085106382979', '0.7063829787234043', '0.705531914893617', '0.7038297872340425', '0.703404255319149', '0.7025531914893617', '0.7008510638297872', '0.7', '0.6978723404255319', '0.6974468085106382', '0.6965957 ...

# %%
for line in run_simulation(sddpath, 'Spectrum'):
  if "No" not in line:
    print(line)
# Out:
# ['0', '47', '0', '43', '10', '2', '0', '0', '0', '0', '1']
